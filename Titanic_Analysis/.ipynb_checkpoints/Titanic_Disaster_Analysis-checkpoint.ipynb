# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
titanic_train_data = pd.read_csv('train.csv')
titanic_test_data = pd.read_csv('test.csv')

# %%
print(titanic_train_data.shape, titanic_test_data.shape)
# Out:
# (891, 12) (418, 11)

# %%
titanic_train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### DATA EXPLORATION

# %%
# number of rows and columns in dataset
titanic_train_data.shape
# Out:
# (891, 12)

# %%
# All the columns 
titanic_train_data.columns.values
# Out:
# array(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object)

# %%
# Some information about the data
titanic_train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Number of missing values in each column
titanic_train_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Unique values in each column
titanic_train_data.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
# Some statistical measures about the data
titanic_train_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Seperate the data into numeric and categorical variables

df_num = titanic_train_data[['Age', 'Fare', 'SibSp', 'Parch']]
df_cat = titanic_train_data[['Survived', 'Pclass', 'Sex', 'Ticket', 'Cabin', 'Embarked']]

# %%
# Next, let us compare survival rates across the numeric variables. This might reveal some interesting insights:

pd.pivot_table(data=titanic_train_data, index = 'Survived', values = ['Age', 'Fare', 'SibSp', 'Parch'])
# Out:
#                 Age       Fare     Parch     SibSp
# Survived
# 0         30.626179  22.117887  0.329690  0.553734
# 1         28.343690  48.395408  0.464912  0.473684

# %%
# Comparing survival rates now across the categorical variables.

print(pd.pivot_table(titanic_train_data, index = 'Survived', columns = 'Pclass', values = 'Ticket' ,aggfunc ='count'))
print()

print(pd.pivot_table(titanic_train_data, index = 'Survived', columns = 'Sex',  values = 'Ticket' ,aggfunc ='count'))
print()

print(pd.pivot_table(titanic_train_data, index = 'Survived', columns = 'Embarked',   values = 'Ticket' ,aggfunc ='count'))
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119
#
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109
#
# Embarked   C   Q    S
# Survived
# 0         75  47  427
# 1         93  30  217

# %% [markdown]
#    ### DATA VISUALIZATION

# %%
# Now let’s make plots of the numeric data:

num_cols = df_num.columns
num_cols_count = len(df_num.columns)

fig, axes = plt.subplots(2, 2, figsize=(12, 8))
axes = axes.flatten()

for i in range(num_cols_count):
    axes[i].hist(df_num[num_cols[i]])
    axes[i].set_title(num_cols[i])

plt.show()

# %% [markdown]
# #### So as we can see, most of the distributions are scattered, except Age, it’s pretty normalized.

# %%
# Let's make distribution plot 

fig, axes = plt.subplots(2, 2, figsize=(12,8)) 
axes = axes.flatten()

for i,column in enumerate(df_num.columns):
    sns.distplot(df_num[column], ax=axes[i])
    axes[i].set_title(column)
    
plt.tight_layout() # Adjust layout
plt.show()

# %%
# For categorical variables:

fig, axes = plt.subplots(3, 2, figsize=(12,8)) 
axes = axes.flatten()

for i, column in enumerate(df_cat.columns):
    sns.barplot(x=df_cat[column].value_counts().index, y=df_cat[column].value_counts(), ax=axes[i])
    axes[i].set_xlabel(column)  # Set the x-axis label
    axes[i].set_ylabel('Count')  # Set the y-axis label

plt.tight_layout()
plt.show()

# %%
# Or we can use Countplot also

# Finding the number of people survived and not survived
print(titanic_train_data['Survived'].value_counts())

# Countplot for survived column
sns.countplot('Survived', data=titanic_train_data)
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
print(titanic_train_data['Sex'].value_counts())

# Countplot for sex column
sns.countplot('Sex', data=titanic_train_data)
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
# Number of survivors genderwise
sns.countplot('Sex', hue='Survived', data=titanic_train_data)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
# Countplot for Pclass column
sns.countplot('Pclass', data=titanic_train_data)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
sns.countplot('Pclass', hue='Survived', data=titanic_train_data)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
class_fare = titanic_train_data.pivot_table(index='Pclass', values='Fare')
print(class_fare)
class_fare.plot(kind='bar')
plt.xlabel('Pclass')
plt.ylabel('Avg Fare')
plt.xticks(rotation=0)
plt.show()
# Out:
#              Fare
# Pclass
# 1       84.154687
# 2       20.662183
# 3       13.675550

# %%
sns.barplot(data=titanic_train_data, x='Pclass', y='Fare', hue='Survived')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Fare'>

# %%
#  Next, we plot a correlation between the numeric columns

df_num.corr()
# Out:
#             Age      Fare     SibSp     Parch
# Age    1.000000  0.096067 -0.308247 -0.189119
# Fare   0.096067  1.000000  0.159651  0.216225
# SibSp -0.308247  0.159651  1.000000  0.414838
# Parch -0.189119  0.216225  0.414838  1.000000

# %%
# Plotting a correlation heatmap between the numeric columns

sns.heatmap(df_num.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### FEATURE ENGINEERING

# %% [markdown]
# ###### If we look at the actual cabin data, we see that there’s basically a letter and then a number. The letters might signify what type of cabin it is, where on the ship it is, which floor, which Class it is for, etc. And the numbers might signify the Cabin number. Let us first split them into individual cabins and see whether someone owned more than a single cabin.

# %%
titanic_train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_train_data['cabin_multiple'] = titanic_train_data.Cabin.apply(lambda x: 0 if pd.isna(x) else len(x.split(' ')))
titanic_train_data['cabin_multiple'].value_counts()
# Out:
# 0    687
# 1    180
# 2     16
# 3      6
# 4      2
# Name: cabin_multiple, dtype: int64

# %% [markdown]
# ###### It looks like the vast majority did not have individual cabins, and only a few people owned more than one cabins.

# %%
# Now let’s see whether the survival rates depend on this

pd.pivot_table(data=titanic_train_data, index='Survived', columns='cabin_multiple', values='Ticket', aggfunc='count')
# Out:
# cabin_multiple      0      1    2    3    4
# Survived
# 0               481.0   58.0  7.0  3.0  NaN
# 1               206.0  122.0  9.0  3.0  2.0

# %% [markdown]
# ###### Next, let us look at the actual letter of the cabin they were in. So you could expect that the cabins with the same letter are roughly in the same locations, or on the same floors, and logically if a cabin was near the lifeboats, they had a better chance of survival. Let us look into that:

# %%
titanic_train_data['cabin_adv'] = titanic_train_data.Cabin.apply(lambda x: str(x)[0])

print(titanic_train_data.cabin_adv.value_counts())
pd.pivot_table(titanic_train_data,index='Survived',columns='cabin_adv', values = 'Name', aggfunc='count')
# Out:
# n    687
# C     59
# B     47
# D     33
# E     32
# A     15
# F     13
# G      4
# T      1
# Name: cabin_adv, dtype: int64
# cabin_adv    A     B     C     D     E    F    G    T      n
# Survived
# 0          8.0  12.0  24.0   8.0   8.0  5.0  2.0  1.0  481.0
# 1          7.0  35.0  35.0  25.0  24.0  8.0  2.0  NaN  206.0

# %% [markdown]
# ###### We can also look at the title of individual passengers. And whether it played any role in them getting a seat in the lifeboats.

# %%
titanic_train_data['name_title'] = titanic_train_data.Name.apply(lambda x: x.split(',')[1].split('.')[0].strip())
titanic_train_data['name_title'].value_counts()
# Out:
# Mr              517
# Miss            182
# Mrs             125
# Master           40
# Dr                7
# Rev               6
# Mlle              2
# Major             2
# Col               2
# the Countess      1
# Capt              1
# Ms                1
# Sir               1
# Lady              1
# Mme               1
# Don               1
# Jonkheer          1
# Name: name_title, dtype: int64

# %%
pd.pivot_table(data=titanic_train_data, index='Survived', columns='name_title', values='Name', aggfunc='count')
# Out:
# name_title  Capt  Col  Don   Dr  Jonkheer  Lady  Major  Master   Miss  Mlle  \
# Survived
# 0            1.0  1.0  1.0  4.0       1.0   NaN    1.0    17.0   55.0   NaN
# 1            NaN  1.0  NaN  3.0       NaN   1.0    1.0    23.0  127.0   2.0
#
# name_title  Mme     Mr   Mrs   Ms  Rev  Sir  the Countess
# Survived
# 0           NaN  436.0  26.0  NaN  6.0  NaN           NaN
# 1           1.0   81.0  99.0  1.0  NaN  1.0           1.0

# %% [markdown]
# ###### We can also look at the passengers who were travelling alone and whether it had any effect on survival rate

# %%
titanic_train_data['Travelling Alone'] = titanic_train_data.apply(lambda row: row.SibSp == 0 and row.Parch == 0, axis = 1)

titanic_train_data.loc[titanic_train_data['Travelling Alone'] == True, 'Travelling Alone'] = 1
titanic_train_data.loc[titanic_train_data['Travelling Alone'] == False, 'Travelling Alone'] = 0

titanic_train_data['Travelling Alone'].value_counts()
# Out:
# 1    537
# 0    354
# Name: Travelling Alone, dtype: int64

# %%
pd.pivot_table(data=titanic_train_data, index='Survived', columns='Travelling Alone', values='Name', aggfunc='count')
# Out:
# Travelling Alone    0    1
# Survived
# 0                 175  374
# 1                 179  163

# %%
titanic_train_data['Family Size'] = titanic_train_data.apply(lambda row: row.SibSp + row.Parch, axis = 1)
titanic_train_data['Family Size'].value_counts()
# Out:
# 0     537
# 1     161
# 2     102
# 3      29
# 5      22
# 4      15
# 6      12
# 10      7
# 7       6
# Name: Family Size, dtype: int64

# %%
pd.pivot_table(data=titanic_train_data, index='Survived', columns='Family Size', values='Name', aggfunc='count')
# Out:
# Family Size     0     1     2     3     4     5    6    7    10
# Survived
# 0            374.0  72.0  43.0   8.0  12.0  19.0  8.0  6.0  7.0
# 1            163.0  89.0  59.0  21.0   3.0   3.0  4.0  NaN  NaN

# %% [markdown]
# ### HANDLING MISSING VALUES

# %%
# Visualizing null values

sns.heatmap(titanic_train_data.isnull())
# Out:
# <AxesSubplot:>

# %%
titanic_train_data['Embarked'].mode()[0]
# Out:
# 'S'

# %%
# Replacing the missing value in "Embarked" column with mode value
titanic_train_data['Embarked'].fillna(titanic_train_data['Embarked'].mode()[0], inplace=True)

# %%
# Replacing the missing values in "Age" column with mean value
titanic_train_data['Age'].fillna(titanic_train_data['Age'].mean(), inplace=True)

# %%
titanic_train_data.isnull().sum()
# Out:
# PassengerId           0
# Survived              0
# Pclass                0
# Name                  0
# Sex                   0
# Age                   0
# SibSp                 0
# Parch                 0
# Ticket                0
# Fare                  0
# Cabin               687
# Embarked              0
# cabin_multiple        0
# cabin_adv             0
# name_title            0
# Travelling Alone      0
# Family Size           0
# dtype: int64

# %% [markdown]
# ###### Later I will drop Cabin column

# %% [markdown]
# ### Normalizing the "Fare" column to have a more normal distribution

# %%
sns.distplot(titanic_train_data['Fare'])
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Density'>

# %%
titanic_train_data['Fare'] = np.log1p(titanic_train_data['Fare'])

# %%
# After Log Transformation on Fare Column

sns.distplot(titanic_train_data['Fare'])
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Density'>

# %% [markdown]
# ### Correlation Matrix

# %%
corr = titanic_train_data.corr()
plt.figure(figsize=(10,6))
sns.heatmap(corr, annot=True, cmap='PiYG')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Dropping unnecessary columns

# %%
titanic_train_data.columns.tolist()
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked',
#  'cabin_multiple',
#  'cabin_adv',
#  'name_title',
#  'Travelling Alone',
#  'Family Size']

# %%
titanic_train_data.drop(columns=['Cabin', 'Name', 'Ticket', 'PassengerId'], axis=1, inplace=True)

# %%
titanic_train_data.isnull().sum()
# Out:
# Survived            0
# Pclass              0
# Sex                 0
# Age                 0
# SibSp               0
# Parch               0
# Fare                0
# Embarked            0
# cabin_multiple      0
# cabin_adv           0
# name_title          0
# Travelling Alone    0
# Family Size         0
# dtype: int64

# %% [markdown]
# ### Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
titanic_train_data['cabin_adv'].unique()
# Out:
# array(['n', 'C', 'E', 'G', 'D', 'A', 'B', 'F', 'T'], dtype=object)

# %%
titanic_train_data['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
titanic_train_data['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
titanic_train_data['name_title'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'the Countess',
#        'Jonkheer'], dtype=object)

# %%
cols = ['Sex', 'Embarked', 'cabin_adv', 'name_title']

# %%
encoder = LabelEncoder()

# %%
for col in cols:
    titanic_train_data[col] = encoder.fit_transform(titanic_train_data[col])

titanic_train_data.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch      Fare  Embarked  \
# 0         0       3    1  22.0      1      0  2.110213         2
# 1         1       1    0  38.0      1      0  4.280593         0
# 2         1       3    0  26.0      0      0  2.188856         2
# 3         1       1    0  35.0      1      0  3.990834         2
# 4         0       3    1  35.0      0      0  2.202765         2
#
#    cabin_multiple  cabin_adv  name_title Travelling Alone  Family Size
# 0               0          8          11                0            1
# 1               1          2          12                0            1
# 2               0          8           8                1            0
# 3               1          2          12                0            1
# 4               0          8          11                1            0

# %% [markdown]
# ### Separating Features and Target

# %%
X = titanic_train_data.drop(columns=['Survived'])
y = titanic_train_data['Survived']

# %% [markdown]
# ### Model Training

# %%
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
def train_model(model):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=30)
    model.fit(X_train, y_train)
    
    # Accuracy score of training data
    X_train_prediction = model.predict(X_train)
    training_data_accuracy = accuracy_score(y_train, X_train_prediction)
    print("Accuracy score of training data:", training_data_accuracy)
    print()
    
    # Accuracy score of testing data
    X_test_prediction = model.predict(X_test)
    testing_data_accuracy = accuracy_score(y_test, X_test_prediction)
    print("Accuracy score of testing data:", testing_data_accuracy)
    print()
    
    # Cross Validation Score
    cv = cross_val_score(model, X, y, cv=5)
    print("CV Score:", cv.mean())
    print()
    
    # Classfication Report
    print("Classification Report:")
    print(classification_report(y_test, X_test_prediction))
    
    # Confusion Matrix
    print("Confusion Matrix:")
    mat = pd.DataFrame(confusion_matrix(y_test, X_test_prediction), columns=['Predicted No', 'Predicted Yes'], 
                                                          index=['Actual No', 'Actual Yes'])
    print(mat)

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
train_model(model)
# Out:
# Accuracy score of training data: 0.8070469798657718
#
# Accuracy score of testing data: 0.7966101694915254
#
# CV Score: 0.792379637185362
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.86      0.84       179
#            1       0.76      0.70      0.73       116
#
#     accuracy                           0.80       295
#    macro avg       0.79      0.78      0.78       295
# weighted avg       0.79      0.80      0.79       295
#
# Confusion Matrix:
#             Predicted No  Predicted Yes
# Actual No            154             25
# Actual Yes            35             81

# %%
#  K Nearest Neighbour
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()
train_model(knn)
# Out:
# Accuracy score of training data: 0.825503355704698
#
# Accuracy score of testing data: 0.7694915254237288
#
# CV Score: 0.7643399661038227
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.87      0.82       179
#            1       0.75      0.62      0.68       116
#
#     accuracy                           0.77       295
#    macro avg       0.76      0.74      0.75       295
# weighted avg       0.77      0.77      0.76       295
#
# Confusion Matrix:
#             Predicted No  Predicted Yes
# Actual No            155             24
# Actual Yes            44             72

# %%
# Support Vector Classifier
from sklearn.svm import SVC

svc = SVC(probability = True)
train_model(svc)
# Out:
# Accuracy score of training data: 0.7281879194630873
#
# Accuracy score of testing data: 0.7084745762711865
#
# CV Score: 0.7172054484966417
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.86      0.78       179
#            1       0.69      0.47      0.56       116
#
#     accuracy                           0.71       295
#    macro avg       0.70      0.67      0.67       295
# weighted avg       0.70      0.71      0.70       295
#
# Confusion Matrix:
#             Predicted No  Predicted Yes
# Actual No            154             25
# Actual Yes            61             55
